# %%
ls ../models/ssd_mobilenet_v2__taco/
# Out:
# checkpoint                  ckpt-5.data-00000-of-00001
# ckpt-1.data-00000-of-00001  ckpt-5.index
# ckpt-1.index                ckpt-6.data-00000-of-00001
# ckpt-2.data-00000-of-00001  ckpt-6.index
# ckpt-2.index                ckpt-7.data-00000-of-00001
# ckpt-3.data-00000-of-00001  ckpt-7.index
# ckpt-3.index                eval/
# ckpt-4.data-00000-of-00001  pipeline.config
# ckpt-4.index                train/

# %%
# !python model_main_tf2.py --model_dir=../models/ssd_mobilenet_v2__taco --pipeline_config_path=../models/ssd_mobilenet_v2__taco/pipeline.config --checkpoint_dir=../models/ssd_mobilenet_v2__taco/
# Out:
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0624 10:17:36.498423 139885204719424 model_lib_v2.py:1090] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0624 10:17:36.498535 139885204719424 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0624 10:17:36.498579 139885204719424 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0624 10:17:36.498618 139885204719424 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# ...
